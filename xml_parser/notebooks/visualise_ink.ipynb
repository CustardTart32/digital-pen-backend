# %%
import json 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize

# %%
with open("../data/uploaded_ink/JmYyDg5SFzmarFuQBaog.json") as f:
    ink = json.load(f)

# %%
plt.plot(ink["x"], ink["y"])
plt.gca().invert_yaxis()
plt.show()

# %%
X = np.swapaxes(np.array([ink["x"], ink["y"], ink["t"]]), 0 , 1)

# %%
X_norm = normalize(X, axis=0)

# %%
kmeans = KMeans(n_clusters=18).fit(X_norm)

# %%
print(kmeans.labels_)
# Out:
# [13 13 13 ...  1  1  1]

# %%
u_labels = np.unique(kmeans.labels_)

for i in u_labels:
    plt.scatter(X[labels == i , 0] , X[labels == i , 1] , label = i, s = 1)
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
X = np.swapaxes(np.array([ink["x"], ink["y"]]), 0 , 1) 
X_norm = normalize(X, axis=0)

# %%
from sklearn.cluster import DBSCAN

clustering = DBSCAN(eps=0.001, min_samples=5).fit(X_norm)

# %%
u_labels = np.unique(clustering.labels_)

for i in u_labels:
    plt.scatter(X[labels == i , 0] , X[labels == i , 1] , label = i, s = 1)
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
from sklearn.mixture import GaussianMixture

gm = GaussianMixture(n_components=18, random_state=0).fit(X_norm)

# %%
plt.scatter(gm.mea)
